# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
from sklearn.cluster import KMeans

# %%
df =  pd.read_csv("Customers.csv")
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
customer_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
customer_data.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
wcss = []

# %%
for i in range(1,11):
    kmeans = KMeans(n_clusters=i , init='k-means++', random_state=0 )
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

# %%
plt.plot(range(1,11), wcss)
plt.title('elbow method')
plt.xlabel('no ofclusters')
plt.ylabel('wcss value')
plt.show()

# %%
kmeansmodel = KMeans(n_clusters = 5, init='k-means++', random_state=0)

# %%
y_kmeans = kmeansmodel.fit_predict(X)

# %%
plt.scatter(X[y_kmeans == 0,0], X[y_kmeans == 0,1], s= 50, c= "blue", label='Customer 1' )
plt.scatter(X[y_kmeans == 1,0], X[y_kmeans == 1,1], s= 50, c= "red", label='Customer 2' )
plt.scatter(X[y_kmeans == 2,0], X[y_kmeans == 2,1], s= 50, c= "orange", label='Customer 3' )
plt.scatter(X[y_kmeans == 3,0], X[y_kmeans == 3,1], s= 50, c= "black", label='Customer 4' )
plt.scatter(X[y_kmeans == 4,0], X[y_kmeans == 4,1], s= 50, c= "purple", label='Customer 5' )
plt.scatter(X[y_kmeans == 5,0], X[y_kmeans == 5,1], s= 50, c= "cyan", label='Customer 6' )
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=100,c = 'yellow', label= 'Centroids')
plt.title('Cluster of customers')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()
